# %%
import numpy as np 
import pandas as pd 
import mysql.connector
from sqlalchemy import text
import getpass
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.orm import relationship, sessionmaker,declarative_base

# %%
saved_password = getpass.getpass()

# %%
user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")

# %%
# %store -r clean_comments
# %store -r locations
# %store -r courses
# %store -r badges
# %store -r schools
# %store -r costs

# %%
Base = declarative_base()

class School(Base):
    __tablename__ = 'school'
    school_id = Column(Integer,primary_key=True)
    school  = Column(String(50))
    web_site = Column(String(100))
    description_ = Column(String(10000))

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

school_objects = [School(     school_id = row['school_id'],
                                school = row['school'],    
                                web_site = row['website'],
                                description_ = row['description']) 
                                for _, row in schools.iterrows()]
session.add_all(school_objects)
session.commit()


session.close()

# %%
Base = declarative_base()

class Comments(Base):
    __tablename__ = 'comments'
    school_id = Column(Integer)
    id = Column(Integer,primary_key=True, autoincrement=True)
    name_ = Column(String(50))
    anonymous = Column(Integer)
    grad_yaer = Column(String(50))
    is_alumni = Column(Integer)
    job_title = Column(String(500))
    tagline = Column(String(250))
    creat_at = Column(String(50))
    program = Column(String(50))
    overall_score = Column(Integer)
    overall = Column(Integer)
    curriculum = Column(Integer)
    job_support = Column(Integer)
    comment_txt = Column(String)
    school  = Column(String(50))
    

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

comments_objects = [Comments(   school_id = row['school_id'],
                                name_ = row['name'],
                                anonymous = row['anonymous'],
                                grad_yaer = row['graduatingYear'],
                                is_alumni = row['isAlumni'],
                                job_title = row['jobTitle'],
                                tagline = row['tagline'],
                                creat_at = row['createdAt'],
                                program = row['program'],
                                overall_score = row['overallScore'],
                                overall = row['overall'],
                                curriculum = row['curriculum'],
                                job_support = row['jobSupport'],
                                comment_txt = row['review_body'],
                                school = row['school']) 
                                for _, row in clean_comments.iterrows()]
session.add_all(comments_objects)
session.commit()

session.close()

# %%
Base = declarative_base()

class COST(Base):
    __tablename__ = 'costs'
    school_id = Column(Integer)
    id = Column(Integer,primary_key=True, autoincrement=True)
    school_name  = Column(String(50))
    course_name = Column(String(50))
    duration_weeks = Column(String(50))
    cost = Column(Integer)
    
    

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

cost_objects = [COST(   school_id = row['school_id'],
                        school_name = row['school_name'],
                        course_name = row['course_name'],
                        duration_weeks = row['duration'],
                        cost = row['cost']) 
                        for _, row in costs.iterrows()]
session.add_all(cost_objects)
session.commit()

session.close()

# %%
Base = declarative_base()

class COURSE(Base):
    __tablename__ = 'courses'
    school_id = Column(Integer)
    id = Column(Integer,primary_key=True, autoincrement=True)
    school  = Column(String(50))
    course = Column(String(100))
    
    

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

course_objects = [COURSE(   school_id = row['school_id'],
                        school = row['school'],
                        course = row['courses'],) 
                        for _, row in courses.iterrows()]
session.add_all(course_objects)
session.commit()

session.close()

# %%
Base = declarative_base()

class BADGE(Base):
    __tablename__ = 'badges'
    school_id = Column(Integer)
    id = Column(Integer,primary_key=True, autoincrement=True)
    school  = Column(String(50))
    name_ = Column(String(50))
    key_word = Column(String(50))
    description_ = Column(String(100))
    
    

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

badge_objects = [BADGE(  school_id = row['school_id'],
                        school = row['school'],
                        name_ = row['name'],
                        key_word = row['keyword'],
                        description_ = row['description']) 
                        for _, row in badges.iterrows()]
session.add_all(badge_objects)
session.commit()

session.close()

# %%
Base = declarative_base()

class LOC(Base):
    __tablename__ = 'locations'
    school_id = Column(Integer)
    id = Column(Integer,primary_key=True, autoincrement=True)
    school  = Column(String(50))
    location  = Column(String(50))
    country_id = Column(String(50))
    country_name = Column(String(50))
    state_id = Column(String(50))
    state_name = Column(String(50))
    city_id = Column(String(50))
    city_name = Column(String(50))
    
    

user = 'root'
data_base = 'bootcamps'
engine = create_engine(f"mysql://{user}:{saved_password}@localhost/{data_base}")
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

loc_objects = [LOC(  school_id = row['school_id'],
                     school = row['school'],
                     location = row['description'],
                     country_id = row['country.id'],
                     country_name = row['country.name'],
                     state_id = row['state.id'],
                     state_name = row['state.name'],
                     city_id = row['city.id'],
                     city_name = row['city.name'])
                     for _, row in locations.iterrows()]
session.add_all(loc_objects)
session.commit()

session.close()
